# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from requests.exceptions import HTTPError
# import seaborn as sns

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/OutputData/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city_data_list = []


# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

print("Beginning Data Retrieval")
print("-----------------------------")

for num, city in enumerate(cities, start=1):    
    response = requests.get(query_url + city)
    if response:
        print(f"Processing Record number {num}, city: {city}")
        # print(type(response.json()))
        js = response.json()
        data = {}
        data['City'] = js['name']
        data['Country'] = js['sys']['country']
        data['Cloudiness'] = js['clouds']['all']
        data['Date'] = js['dt']
        data['Humidity'] = js['main']['humidity']
        data['Latitude'] = js['coord']['lat']
        data['Longitude'] = js['coord']['lon']
        data['Max Temp'] = js['main']['temp_max']
        data['Wind Speed'] = js['wind']['speed']
        city_data_list.append([data['City'], data['Country'], data['Cloudiness'],
                            data['Date'], data['Humidity'], data['Latitude'],
                            data['Longitude'], data['Max Temp'],
                            data['Wind Speed']])
        # print(json.dumps(js, indent=4, sort_keys=True))
    else:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record number 1, city: lebu
# Processing Record number 2, city: upernavik
# City not found. Skipping...
# Processing Record number 4, city: aklavik
# Processing Record number 5, city: port elizabeth
# Processing Record number 6, city: mataura
# Processing Record number 7, city: rikitea
# Processing Record number 8, city: ewa beach
# Processing Record number 9, city: busselton
# Processing Record number 10, city: kungurtug
# Processing Record number 11, city: revelstoke
# Processing Record number 12, city: anadyr
# Processing Record number 13, city: erzin
# Processing Record number 14, city: port alfred
# Processing Record number 15, city: huallanca
# City not found. Skipping...
# Processing Record number 17, city: esperance
# Processing Record number 18, city: dikson
# City not found. Skipping...
# Processing Record number 20, city: ambilobe
# Processing Record number 21, city: calatayud
# Processing Record number 22, city: margate
# Processing Record number 23, city: bluff
# Processing Record number 24, city: bredasdorp
# Processing Record number 25, city: ribeira grande
# Processing Record number 26, city: east london
# Processing Record number 27, city: butaritari
# Processing Record number 28, city: cape town
# Processing Record number 29, city: bethel
# Processing Record number 30, city: cayenne
# Processing Record number 31, city: fortuna
# Processing Record number 32, city: anupgarh
# Processing Record number 33, city: avarua
# Processing Record number 34, city: ushuaia
# Processing Record number 35, city: yeppoon
# Processing Record number 36, city: kahului
# Processing Record number 37, city: dukat
# Processing Record number 38, city: longyearbyen
# Processing Record number 39, city: barrow
# Processing Record number 40, city: komsomolskiy
# Processing Record number 41, city: flinders
# Processing Record number 42, city: mayo
# Processing Record number 43, city: nouadhibou
# Processing Record number 44, city: alice springs
# Processing Record number 45, city: jamestown
# City not found. Skipping...
# Processing Record number 47, city: saint george
# Processing Record number 48, city: bontang
# Processing Record number 49, city: concarneau
# Processing Record number 50, city: yumen
# Processing Record number 51, city: hobart
# Processing Record number 52, city: saint-augustin
# Processing Record number 53, city: yellowknife
# Processing Record number 54, city: fort nelson
# Processing Record number 55, city: georgetown
# City not found. Skipping...
# Processing Record number 57, city: albany
# Processing Record number 58, city: tanggulangin
# Processing Record number 59, city: kijang
# Processing Record number 60, city: mokobeng
# Processing Record number 61, city: alfonsine
# Processing Record number 62, city: mahebourg
# Processing Record number 63, city: hervey bay
# Processing Record number 64, city: mabaruma
# Processing Record number 65, city: alofi
# City not found. Skipping...
# Processing Record number 67, city: hithadhoo
# City not found. Skipping...
# Processing Record number 69, city: saint-philippe
# City not found. Skipping...
# Processing Record number 71, city: provideniya
# Processing Record number 72, city: cherskiy
# Processing Record number 73, city: dossor
# Processing Record number 74, city: talnakh
# Processing Record number 75, city: chokurdakh
# Processing Record number 76, city: shimoda
# Processing Record number 77, city: hilo
# Processing Record number 78, city: gainesville
# Processing Record number 79, city: sao jose de piranhas
# Processing Record number 80, city: talpa
# Processing Record number 81, city: araouane
# Processing Record number 82, city: sault sainte marie
# Processing Record number 83, city: maceio
# Processing Record number 84, city: iracoubo
# Processing Record number 85, city: whitehorse
# Processing Record number 86, city: gat
# Processing Record number 87, city: nyimba
# Processing Record number 88, city: sao filipe
# Processing Record number 89, city: azul
# Processing Record number 90, city: new norfolk
# City not found. Skipping...
# Processing Record number 92, city: soure
# Processing Record number 93, city: castro
# Processing Record number 94, city: torbay
# Processing Record number 95, city: port macquarie
# Processing Record number 96, city: qaanaaq
# City not found. Skipping...
# Processing Record number 98, city: maniitsoq
# Processing Record number 99, city: san ramon
# Processing Record number 100, city: hasaki
# Processing Record number 101, city: ranong
# Processing Record number 102, city: vardo
# Processing Record number 103, city: rio gallegos
# Processing Record number 104, city: tarpon springs
# City not found. Skipping...
# Processing Record number 106, city: alghero
# Processing Record number 107, city: san ignacio
# Processing Record number 108, city: jinchang
# Processing Record number 109, city: atuona
# Processing Record number 110, city: cap malheureux
# Processing Record number 111, city: varhaug
# Processing Record number 112, city: pisco
# Processing Record number 113, city: ekhabi
# Processing Record number 114, city: kapaa
# Processing Record number 115, city: tiksi
# Processing Record number 116, city: gari
# Processing Record number 117, city: zhanaozen
# Processing Record number 118, city: punta arenas
# Processing Record number 119, city: san cristobal
# Processing Record number 120, city: kedrovyy
# Processing Record number 121, city: mangai
# Processing Record number 122, city: aljezur
# Processing Record number 123, city: gotsu
# Processing Record number 124, city: reinosa
# Processing Record number 125, city: manbij
# Processing Record number 126, city: matay
# Processing Record number 127, city: krasnokamensk
# Processing Record number 128, city: kodiak
# Processing Record number 129, city: chitral
# Processing Record number 130, city: surdulica
# Processing Record number 131, city: hamilton
# Processing Record number 132, city: grindavik
# Processing Record number 133, city: haines junction
# Processing Record number 134, city: geraldton
# Processing Record number 135, city: matara
# Processing Record number 136, city: tarbagatay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record number 139, city: saskylakh
# Processing Record number 140, city: galesong
# Processing Record number 141, city: necochea
# Processing Record number 142, city: nawa
# Processing Record number 143, city: jalu
# Processing Record number 144, city: tuktoyaktuk
# Processing Record number 145, city: luderitz
# Processing Record number 146, city: avera
# City not found. Skipping...
# Processing Record number 148, city: ntoum
# Processing Record number 149, city: chuy
# Processing Record number 150, city: saint-pierre
# Processing Record number 151, city: polunochnoye
# Processing Record number 152, city: kisangani
# Processing Record number 153, city: ozu
# Processing Record number 154, city: iqaluit
# Processing Record number 155, city: bulolo
# Processing Record number 156, city: auki
# Processing Record number 157, city: sitka
# Processing Record number 158, city: anloga
# Processing Record number 159, city: vaini
# Processing Record number 160, city: port moresby
# Processing Record number 161, city: dingle
# Processing Record number 162, city: banda aceh
# Processing Record number 163, city: bethanien
# Processing Record number 164, city: arraias
# Processing Record number 165, city: surt
# Processing Record number 166, city: taperoa
# Processing Record number 167, city: port lincoln
# Processing Record number 168, city: kaitangata
# Processing Record number 169, city: hermanus
# Processing Record number 170, city: asyut
# City not found. Skipping...
# Processing Record number 172, city: namatanai
# Processing Record number 173, city: tautira
# Processing Record number 174, city: lasa
# Processing Record number 175, city: pevek
# Processing Record number 176, city: khilok
# Processing Record number 177, city: stropkov
# Processing Record number 178, city: carutapera
# Processing Record number 179, city: izazi
# Processing Record number 180, city: vao
# City not found. Skipping...
# Processing Record number 182, city: beloha
# Processing Record number 183, city: coahuayana
# Processing Record number 184, city: lagoa
# Processing Record number 185, city: poum
# Processing Record number 186, city: raymond
# Processing Record number 187, city: bambous virieux
# Processing Record number 188, city: karaidel
# Processing Record number 189, city: palembang
# Processing Record number 190, city: cabo san lucas
# Processing Record number 191, city: thompson
# Processing Record number 192, city: gayeri
# Processing Record number 193, city: tateyama
# Processing Record number 194, city: phan thiet
# Processing Record number 195, city: tasiilaq
# Processing Record number 196, city: zyryanskoye
# Processing Record number 197, city: puerto ayora
# Processing Record number 198, city: huanren
# Processing Record number 199, city: taltal
# City not found. Skipping...
# Processing Record number 201, city: togur
# City not found. Skipping...
# Processing Record number 203, city: isangel
# Processing Record number 204, city: nsanje
# Processing Record number 205, city: sarkikaraagac
# City not found. Skipping...
# Processing Record number 207, city: bella union
# Processing Record number 208, city: rumphi
# Processing Record number 209, city: beringovskiy
# Processing Record number 210, city: norman wells
# Processing Record number 211, city: kroya
# Processing Record number 212, city: tomatlan
# Processing Record number 213, city: murakeresztur
# Processing Record number 214, city: nishihara
# Processing Record number 215, city: manavalakurichi
# Processing Record number 216, city: sarangani
# City not found. Skipping...
# Processing Record number 218, city: sobolevo
# City not found. Skipping...
# Processing Record number 220, city: orchard homes
# Processing Record number 221, city: aripuana
# Processing Record number 222, city: moyale
# Processing Record number 223, city: ponta do sol
# Processing Record number 224, city: san patricio
# Processing Record number 225, city: quatre cocos
# Processing Record number 226, city: augusto correa
# Processing Record number 227, city: praya
# City not found. Skipping...
# Processing Record number 229, city: trapani
# Processing Record number 230, city: henties bay
# City not found. Skipping...
# Processing Record number 232, city: gainsborough
# Processing Record number 233, city: maymyo
# City not found. Skipping...
# Processing Record number 235, city: ketchikan
# Processing Record number 236, city: mountain home
# Processing Record number 237, city: sao joao da barra
# Processing Record number 238, city: bilibino
# Processing Record number 239, city: acapulco
# City not found. Skipping...
# Processing Record number 241, city: victoria
# Processing Record number 242, city: kharitonovo
# Processing Record number 243, city: weyburn
# Processing Record number 244, city: ahipara
# Processing Record number 245, city: natchitoches
# City not found. Skipping...
# Processing Record number 247, city: seoul
# Processing Record number 248, city: sovetskaya gavan
# Processing Record number 249, city: vila velha
# Processing Record number 250, city: sinnamary
# Processing Record number 251, city: ojinaga
# Processing Record number 252, city: aneho
# Processing Record number 253, city: bathsheba
# Processing Record number 254, city: kavaratti
# Processing Record number 255, city: terney
# Processing Record number 256, city: ondo
# Processing Record number 257, city: sur
# Processing Record number 258, city: san juan
# Processing Record number 259, city: basco
# Processing Record number 260, city: zgierz
# Processing Record number 261, city: leningradskiy
# City not found. Skipping...
# Processing Record number 263, city: gravdal
# Processing Record number 264, city: bosaso
# Processing Record number 265, city: rudsar
# City not found. Skipping...
# Processing Record number 267, city: ilulissat
# Processing Record number 268, city: tarko-sale
# Processing Record number 269, city: uvat
# Processing Record number 270, city: bambari
# Processing Record number 271, city: tokur
# Processing Record number 272, city: nome
# Processing Record number 273, city: tucupita
# Processing Record number 274, city: namibe
# Processing Record number 275, city: mezen
# Processing Record number 276, city: zavodouspenskoye
# Processing Record number 277, city: naryan-mar
# Processing Record number 278, city: katsuura
# Processing Record number 279, city: sasayama
# Processing Record number 280, city: kokopo
# Processing Record number 281, city: severo-kurilsk
# Processing Record number 282, city: lavrentiya
# Processing Record number 283, city: khorramshahr
# Processing Record number 284, city: port-cartier
# Processing Record number 285, city: caravelas
# Processing Record number 286, city: port keats
# Processing Record number 287, city: fairbanks
# Processing Record number 288, city: channel-port aux basques
# Processing Record number 289, city: akureyri
# Processing Record number 290, city: harper
# Processing Record number 291, city: cidreira
# Processing Record number 292, city: albury
# City not found. Skipping...
# Processing Record number 294, city: tonstad
# Processing Record number 295, city: mar del plata
# Processing Record number 296, city: codrington
# Processing Record number 297, city: kalmunai
# Processing Record number 298, city: nikolskoye
# Processing Record number 299, city: kruisfontein
# Processing Record number 300, city: faanui
# Processing Record number 301, city: mugur-aksy
# Processing Record number 302, city: richards bay
# Processing Record number 303, city: zhigansk
# Processing Record number 304, city: romny
# Processing Record number 305, city: sivaki
# Processing Record number 306, city: kirakira
# Processing Record number 307, city: ankpa
# Processing Record number 308, city: mumford
# Processing Record number 309, city: ben tre
# Processing Record number 310, city: shingu
# Processing Record number 311, city: parabel
# Processing Record number 312, city: sakaiminato
# Processing Record number 313, city: bafoulabe
# Processing Record number 314, city: bayanday
# Processing Record number 315, city: rocha
# Processing Record number 316, city: oistins
# Processing Record number 317, city: honiara
# Processing Record number 318, city: cravo norte
# Processing Record number 319, city: westport
# Processing Record number 320, city: itoman
# Processing Record number 321, city: pangai
# Processing Record number 322, city: hamada
# Processing Record number 323, city: santo antonio do leverger
# Processing Record number 324, city: sohbatpur
# Processing Record number 325, city: laurel
# Processing Record number 326, city: vieste
# Processing Record number 327, city: sant julia de loria
# Processing Record number 328, city: sawakin
# Processing Record number 329, city: jacareacanga
# Processing Record number 330, city: santa cruz
# Processing Record number 331, city: glendive
# Processing Record number 332, city: sakaraha
# Processing Record number 333, city: arica
# Processing Record number 334, city: niquelandia
# Processing Record number 335, city: samarai
# Processing Record number 336, city: mao
# Processing Record number 337, city: dunedin
# City not found. Skipping...
# Processing Record number 339, city: ponta delgada
# Processing Record number 340, city: kloulklubed
# Processing Record number 341, city: ayolas
# Processing Record number 342, city: klaksvik
# City not found. Skipping...
# Processing Record number 344, city: ratnagiri
# Processing Record number 345, city: barcelos
# Processing Record number 346, city: grand gaube
# Processing Record number 347, city: naze
# Processing Record number 348, city: nizhniy odes
# Processing Record number 349, city: adria
# Processing Record number 350, city: yulara
# Processing Record number 351, city: meulaboh
# Processing Record number 352, city: litovko
# Processing Record number 353, city: khatanga
# Processing Record number 354, city: havre-saint-pierre
# Processing Record number 355, city: colares
# Processing Record number 356, city: faurei
# City not found. Skipping...
# Processing Record number 358, city: xining
# Processing Record number 359, city: yar-sale
# Processing Record number 360, city: peniche
# Processing Record number 361, city: zhezkazgan
# Processing Record number 362, city: aguimes
# Processing Record number 363, city: cap-aux-meules
# Processing Record number 364, city: causapscal
# Processing Record number 365, city: mezhdurechensk
# City not found. Skipping...
# Processing Record number 367, city: tiarei
# Processing Record number 368, city: turukhansk
# Processing Record number 369, city: bayaguana
# Processing Record number 370, city: port hedland
# Processing Record number 371, city: carnarvon
# Processing Record number 372, city: souillac
# Processing Record number 373, city: huarmey
# Processing Record number 374, city: ostrovnoy
# Processing Record number 375, city: mount gambier
# Processing Record number 376, city: hovd
# Processing Record number 377, city: kadnikov
# Processing Record number 378, city: broome
# Processing Record number 379, city: buraydah
# Processing Record number 380, city: kavieng
# Processing Record number 381, city: lorengau
# Processing Record number 382, city: takapau
# Processing Record number 383, city: cabedelo
# Processing Record number 384, city: el tocuyo
# Processing Record number 385, city: tallahassee
# City not found. Skipping...
# Processing Record number 387, city: makasar
# Processing Record number 388, city: west bay
# Processing Record number 389, city: zhuzhou
# Processing Record number 390, city: marsh harbour
# Processing Record number 391, city: bima
# Processing Record number 392, city: sarab
# Processing Record number 393, city: porto walter
# Processing Record number 394, city: airai
# Processing Record number 395, city: biak
# Processing Record number 396, city: fershampenuaz
# Processing Record number 397, city: auburn
# Processing Record number 398, city: houma
# City not found. Skipping...
# Processing Record number 400, city: antalaha
# Processing Record number 401, city: el alto
# Processing Record number 402, city: alexandria
# Processing Record number 403, city: muros
# Processing Record number 404, city: ulagan
# Processing Record number 405, city: maningrida
# Processing Record number 406, city: tuatapere
# Processing Record number 407, city: temirtau
# City not found. Skipping...
# Processing Record number 409, city: college
# Processing Record number 410, city: saldanha
# Processing Record number 411, city: kurilsk
# Processing Record number 412, city: luchenza
# Processing Record number 413, city: tolyatti
# Processing Record number 414, city: poshekhonye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record number 417, city: coquimbo
# Processing Record number 418, city: verkhoyansk
# Processing Record number 419, city: smithers
# Processing Record number 420, city: mogadishu
# Processing Record number 421, city: sokoni
# Processing Record number 422, city: rey bouba
# Processing Record number 423, city: otradnoye
# Processing Record number 424, city: plettenberg bay
# Processing Record number 425, city: asekeyevo
# Processing Record number 426, city: bemidji
# Processing Record number 427, city: chase
# Processing Record number 428, city: toora-khem
# City not found. Skipping...
# Processing Record number 430, city: bamiantong
# Processing Record number 431, city: oussouye
# Processing Record number 432, city: esna
# Processing Record number 433, city: liberty
# Processing Record number 434, city: te anau
# Processing Record number 435, city: arraial do cabo
# City not found. Skipping...
# Processing Record number 437, city: oparino
# Processing Record number 438, city: fukue
# Processing Record number 439, city: palana
# Processing Record number 440, city: novobiryusinskiy
# Processing Record number 441, city: the valley
# Processing Record number 442, city: mbour
# City not found. Skipping...
# Processing Record number 444, city: coracao de jesus
# Processing Record number 445, city: sawtell
# Processing Record number 446, city: hay river
# Processing Record number 447, city: lompoc
# Processing Record number 448, city: clarksdale
# Processing Record number 449, city: constitucion
# Processing Record number 450, city: melivoia
# Processing Record number 451, city: nanortalik
# City not found. Skipping...
# Processing Record number 453, city: bandarbeyla
# City not found. Skipping...
# Processing Record number 455, city: fallon
# Processing Record number 456, city: belmonte
# Processing Record number 457, city: nago
# Processing Record number 458, city: cody
# Processing Record number 459, city: los chiles
# Processing Record number 460, city: buchanan
# Processing Record number 461, city: piacabucu
# Processing Record number 462, city: pavlysh
# Processing Record number 463, city: teguise
# Processing Record number 464, city: iberia
# Processing Record number 465, city: husavik
# Processing Record number 466, city: lind
# Processing Record number 467, city: canutama
# Processing Record number 468, city: sibu
# Processing Record number 469, city: murgab
# Processing Record number 470, city: chenghai
# Processing Record number 471, city: delemont
# Processing Record number 472, city: lazaro cardenas
# Processing Record number 473, city: bayshore gardens
# Processing Record number 474, city: porto novo
# Processing Record number 475, city: katiola
# Processing Record number 476, city: mundi
# Processing Record number 477, city: tymovskoye
# Processing Record number 478, city: luganville
# Processing Record number 479, city: la macarena
# Processing Record number 480, city: liku
# Processing Record number 481, city: dudinka
# Processing Record number 482, city: lucapa
# Processing Record number 483, city: nemuro
# Processing Record number 484, city: lodja
# Processing Record number 485, city: hoquiam
# Processing Record number 486, city: mangalam
# Processing Record number 487, city: tigil
# Processing Record number 488, city: tura
# Processing Record number 489, city: portland
# Processing Record number 490, city: amahai
# Processing Record number 491, city: dunda
# Processing Record number 492, city: komatipoort
# Processing Record number 493, city: hambantota
# City not found. Skipping...
# City not found. Skipping...
# Processing Record number 496, city: batouri
# Processing Record number 497, city: kropotkin
# City not found. Skipping...
# Processing Record number 499, city: walvis bay
# City not found. Skipping...
# Processing Record number 501, city: skibbereen
# Processing Record number 502, city: pangnirtung
# Processing Record number 503, city: shenjiamen
# City not found. Skipping...
# Processing Record number 505, city: hami
# City not found. Skipping...
# City not found. Skipping...
# Processing Record number 508, city: tessalit
# City not found. Skipping...
# Processing Record number 510, city: pochutla
# Processing Record number 511, city: hastings
# Processing Record number 512, city: plasnica
# Processing Record number 513, city: la paz
# Processing Record number 514, city: keflavik
# Processing Record number 515, city: mutoko
# Processing Record number 516, city: freeport
# Processing Record number 517, city: cocula
# Processing Record number 518, city: camopi
# Processing Record number 519, city: pahrump
# City not found. Skipping...
# Processing Record number 521, city: santa rosa
# Processing Record number 522, city: birao
# Processing Record number 523, city: arlit
# Processing Record number 524, city: gejiu
# Processing Record number 525, city: presidencia roque saenz pena
# Processing Record number 526, city: udachnyy
# Processing Record number 527, city: rincon
# Processing Record number 528, city: chapais
# Processing Record number 529, city: shubarkuduk
# City not found. Skipping...
# Processing Record number 531, city: toluviejo
# Processing Record number 532, city: tecoanapa
# City not found. Skipping...
# Processing Record number 534, city: okha
# Processing Record number 535, city: aksarka
# Processing Record number 536, city: tsabong
# Processing Record number 537, city: hofn
# Processing Record number 538, city: ancud
# Processing Record number 539, city: sioux lookout
# Processing Record number 540, city: washington
# Processing Record number 541, city: nosy varika
# City not found. Skipping...
# Processing Record number 543, city: vestmanna
# Processing Record number 544, city: oia
# Processing Record number 545, city: crestview
# Processing Record number 546, city: suluq
# Processing Record number 547, city: eastbourne
# Processing Record number 548, city: kandila
# Processing Record number 549, city: srednekolymsk
# Processing Record number 550, city: tortoli
# Processing Record number 551, city: half moon bay
# Processing Record number 552, city: miri
# Processing Record number 553, city: isiro
# Processing Record number 554, city: kesova gora
# Processing Record number 555, city: ekibastuz
# Processing Record number 556, city: behbahan
# Processing Record number 557, city: mokhsogollokh
# Processing Record number 558, city: ayan
# Processing Record number 559, city: olga
# Processing Record number 560, city: tevaitoa
# Processing Record number 561, city: limon
# Processing Record number 562, city: riyadh
# Processing Record number 563, city: ulaangom
# Processing Record number 564, city: lokosovo
# Processing Record number 565, city: andra
# City not found. Skipping...
# Processing Record number 567, city: panzhihua
# City not found. Skipping...
# Processing Record number 569, city: aasiaat
# Processing Record number 570, city: altagracia de orituco
# Processing Record number 571, city: manggar
# Processing Record number 572, city: bealanana
# Processing Record number 573, city: mujiayingzi
# Processing Record number 574, city: mecca
# Processing Record number 575, city: verkhnevilyuysk
# Processing Record number 576, city: bahir dar
# City not found. Skipping...
# Processing Record number 578, city: ust-barguzin
# Processing Record number 579, city: sorsk
# Processing Record number 580, city: awbari
# Processing Record number 581, city: moctezuma
# Processing Record number 582, city: kenai
# City not found. Skipping...
# Processing Record number 584, city: sao felix do xingu
# Processing Record number 585, city: strezhevoy
# Processing Record number 586, city: mitzic
# Processing Record number 587, city: slobidka
# City not found. Skipping...
# Processing Record number 589, city: touros
# Processing Record number 590, city: eureka
# Processing Record number 591, city: mnogovershinnyy
# Processing Record number 592, city: alyangula
# Processing Record number 593, city: methoni
# Processing Record number 594, city: merrill
# Processing Record number 595, city: dubbo
# Processing Record number 596, city: sept-iles
# Processing Record number 597, city: lyngseidet
# City not found. Skipping...
# Processing Record number 599, city: inuvik
# Processing Record number 600, city: darnah
# Processing Record number 601, city: lima
# Processing Record number 602, city: axim
# Processing Record number 603, city: mattawa
# Processing Record number 604, city: taybad
# Processing Record number 605, city: goderich
# Processing Record number 606, city: bassano
# Processing Record number 607, city: beruwala

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Conver raw data to DataFrame
city_data_df = pd.DataFrame(city_data_list, columns=data.keys())
city_data_df.count()
# Out:
# City          546
# Country       546
# Cloudiness    546
# Date          546
# Humidity      546
# Latitude      546
# Longitude     546
# Max Temp      546
# Wind Speed    546
# dtype: int64

# %%
# Export the city data into a.csv.
city_data_df.to_csv(output_data_file, index=False)

# Display a preview of the DataFrame
city_data_df.head()
# Out:
#              City Country  Cloudiness        Date  Humidity  Latitude  \
# 0            Lebu      ET          20  1572038786        44      8.96
# 1       Upernavik      GL         100  1572038786        65     72.79
# 2         Aklavik      CA          40  1572038522        79     68.22
# 3  Port Elizabeth      US          40  1572038786        63     39.31
# 4         Mataura      NZ           0  1572038786        65    -46.19
#
#    Longitude  Max Temp  Wind Speed
# 0      38.73     59.00       12.75
# 1     -56.15     34.47       12.57
# 2    -135.01     19.40        3.36
# 3     -74.98     66.99        3.36
# 4     168.86     57.92        0.98

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for Latitude vs Temperature.
plt.scatter(city_data_df['Latitude'], city_data_df['Max Temp'], c='cyan',
            marker='o', edgecolors='dimgray')

# Incorporate the other graph properties
plt.ylim(-5, 105)
plt.title('City Latitude vs. Max Temperature (10/23/2019)', fontweight="bold")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.grid(True)
# sns.regplot(city_data_df['Latitude'], city_data_df['Max Temp'])

# Save the figure as .png.
plt.savefig('C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/Images/Latitude-MaxTemp.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for Latitude vs Humidity.
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'], c='purple',
            marker='o', edgecolors='dimgray')

# Incorporate the other graph properties
plt.ylim(-5, 105)
plt.title('City Latitude vs. Humidity (10/23/2019)', fontweight="bold")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
# sns.regplot(city_data_df['Latitude'], city_data_df['Humidity'])

# Save the figure as .png.
plt.savefig('C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/Images/Latitude-Humidity.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Latitude vs Cloudiness.
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'], c='silver',
            marker='o', edgecolors='maroon')

# Incorporate the other graph properties
plt.ylim(-5, 105)
plt.title('City Latitude vs. Cloudiness (10/23/2019)', fontweight="bold")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
#sns.regplot(city_data_df['Latitude'], city_data_df['Cloudiness'])


# Save the figure as .png.
plt.savefig('C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/Images/Latitude-Cloudiness.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs Wind Speed.
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'], c='maroon',
            marker='o', edgecolors='dimgray')

# Incorporate the other graph properties
plt.ylim(-5, max(city_data_df['Wind Speed'])+5)
plt.title('City Latitude vs. Wind Speed (10/23/2019)', fontweight="bold")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
#sns.regplot(city_data_df['Latitude'], city_data_df['Wind Speed'])

# Save the figure as .png.
plt.savefig('C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/Images/Latitude-Wind Speed.png')

# Show plot
plt.show()
