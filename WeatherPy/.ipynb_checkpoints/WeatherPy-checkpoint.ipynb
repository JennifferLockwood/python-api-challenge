# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from requests.exceptions import HTTPError

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/OutputData/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city_data_list = []


# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

print("Beginning Data Retrieval")
print("-----------------------------")

for num, city in enumerate(cities, start=1):    
    response = requests.get(query_url + city)
    if response:
        print(f"Processing Record number {num}, city: {city}")
        # print(type(response.json()))
        js = response.json()
        data = {}
        data['City'] = js['name']
        data['Country'] = js['sys']['country']
        data['Cloudiness'] = js['clouds']['all']
        data['Date'] = js['dt']
        data['Humidity'] = js['main']['humidity']
        data['Latitude'] = js['coord']['lat']
        data['Longitude'] = js['coord']['lon']
        data['Max Temp'] = js['main']['temp_max']
        data['Wind Speed'] = js['wind']['speed']
        city_data_list.append([data['City'], data['Country'], data['Cloudiness'],
                            data['Date'], data['Humidity'], data['Latitude'],
                            data['Longitude'], data['Max Temp'],
                            data['Wind Speed']])
        # print(json.dumps(js, indent=4, sort_keys=True))
    else:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record number 1, city: mahebourg
# Processing Record number 2, city: iturama
# Processing Record number 3, city: kapaa
# Processing Record number 4, city: hermanus
# Processing Record number 5, city: plouzane
# Processing Record number 6, city: san andres
# City not found. Skipping...
# Processing Record number 8, city: mount gambier
# City not found. Skipping...
# Processing Record number 10, city: ushuaia
# Processing Record number 11, city: jamestown
# Processing Record number 12, city: vila velha
# Processing Record number 13, city: ribeira grande
# Processing Record number 14, city: tuatapere
# Processing Record number 15, city: mataura
# Processing Record number 16, city: chokurdakh
# Processing Record number 17, city: cape town
# Processing Record number 18, city: paraiso
# Processing Record number 19, city: dingle
# Processing Record number 20, city: bambous virieux
# Processing Record number 21, city: pinawa
# Processing Record number 22, city: pokhara
# Processing Record number 23, city: llanes
# City not found. Skipping...
# Processing Record number 25, city: baruun-urt
# Processing Record number 26, city: rodrigues alves
# Processing Record number 27, city: lafia
# Processing Record number 28, city: new norfolk
# Processing Record number 29, city: vaini
# Processing Record number 30, city: salalah
# Processing Record number 31, city: bredasdorp
# Processing Record number 32, city: durango
# Processing Record number 33, city: bolotnoye
# Processing Record number 34, city: atuona
# Processing Record number 35, city: ust-shonosha
# City not found. Skipping...
# Processing Record number 37, city: hamilton
# City not found. Skipping...
# Processing Record number 39, city: okhotsk
# City not found. Skipping...
# Processing Record number 41, city: le port
# Processing Record number 42, city: umm lajj
# Processing Record number 43, city: victoria
# Processing Record number 44, city: mar del plata
# Processing Record number 45, city: barrow
# Processing Record number 46, city: bathsheba
# Processing Record number 47, city: itarema
# Processing Record number 48, city: tiksi
# Processing Record number 49, city: yellowknife
# Processing Record number 50, city: arraial do cabo
# Processing Record number 51, city: faenza
# City not found. Skipping...
# Processing Record number 53, city: gamba
# Processing Record number 54, city: isangel
# Processing Record number 55, city: griffith
# Processing Record number 56, city: emerald
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record number 60, city: mehamn
# Processing Record number 61, city: coquimbo
# Processing Record number 62, city: ust-tsilma
# Processing Record number 63, city: kinkala
# Processing Record number 64, city: albany
# Processing Record number 65, city: sarkand
# Processing Record number 66, city: uglovskoye
# Processing Record number 67, city: bom jesus
# Processing Record number 68, city: talara
# Processing Record number 69, city: kiruna
# Processing Record number 70, city: saskylakh
# Processing Record number 71, city: bluff
# Processing Record number 72, city: punta arenas
# Processing Record number 73, city: lata
# Processing Record number 74, city: helena
# Processing Record number 75, city: nouadhibou
# Processing Record number 76, city: bundi
# Processing Record number 77, city: dunmore town
# Processing Record number 78, city: kruisfontein
# Processing Record number 79, city: talnakh
# Processing Record number 80, city: beba
# Processing Record number 81, city: port elizabeth
# Processing Record number 82, city: chuy
# Processing Record number 83, city: nikolskoye
# City not found. Skipping...
# Processing Record number 85, city: inhambane
# City not found. Skipping...
# Processing Record number 87, city: castro
# Processing Record number 88, city: sitka
# Processing Record number 89, city: grand valley
# City not found. Skipping...
# Processing Record number 91, city: qaanaaq
# Processing Record number 92, city: haines junction
# Processing Record number 93, city: rikitea
# Processing Record number 94, city: guerrero negro
# Processing Record number 95, city: butaritari
# Processing Record number 96, city: benjamin hill
# Processing Record number 97, city: provideniya
# City not found. Skipping...
# Processing Record number 99, city: saint-augustin
# Processing Record number 100, city: sola
# Processing Record number 101, city: hovd
# Processing Record number 102, city: port alfred
# Processing Record number 103, city: kalevala
# City not found. Skipping...
# Processing Record number 105, city: manggar
# Processing Record number 106, city: lithakia
# Processing Record number 107, city: ixtapa
# Processing Record number 108, city: galle
# Processing Record number 109, city: cheyenne
# Processing Record number 110, city: baykit
# Processing Record number 111, city: narsaq
# Processing Record number 112, city: saint-philippe
# City not found. Skipping...
# Processing Record number 114, city: coria
# Processing Record number 115, city: leningradskiy
# City not found. Skipping...
# Processing Record number 117, city: mulege
# Processing Record number 118, city: praia
# Processing Record number 119, city: ancud
# Processing Record number 120, city: hobart
# Processing Record number 121, city: omboue
# Processing Record number 122, city: concepcion
# Processing Record number 123, city: barcelos
# Processing Record number 124, city: samarai
# Processing Record number 125, city: izhma
# Processing Record number 126, city: comodoro rivadavia
# Processing Record number 127, city: rolla
# Processing Record number 128, city: vardo
# City not found. Skipping...
# Processing Record number 130, city: puerto ayora
# Processing Record number 131, city: tayu
# Processing Record number 132, city: hilo
# Processing Record number 133, city: te anau
# Processing Record number 134, city: tuktoyaktuk
# Processing Record number 135, city: ambulu
# Processing Record number 136, city: puerto baquerizo moreno
# Processing Record number 137, city: yerbogachen
# Processing Record number 138, city: balkanabat
# City not found. Skipping...
# Processing Record number 140, city: constitucion
# Processing Record number 141, city: severo-kurilsk
# Processing Record number 142, city: lompoc
# City not found. Skipping...
# City not found. Skipping...
# Processing Record number 145, city: cayenne
# Processing Record number 146, city: okoneshnikovo
# Processing Record number 147, city: mizdah
# Processing Record number 148, city: sijunjung
# Processing Record number 149, city: belmonte
# Processing Record number 150, city: peace river
# City not found. Skipping...
# Processing Record number 152, city: hammerfest
# Processing Record number 153, city: boa vista
# Processing Record number 154, city: ponta pora
# Processing Record number 155, city: hualmay
# Processing Record number 156, city: bethel
# Processing Record number 157, city: airai
# Processing Record number 158, city: klaksvik
# Processing Record number 159, city: lichinga
# Processing Record number 160, city: kaitangata
# Processing Record number 161, city: busselton
# Processing Record number 162, city: asosa
# Processing Record number 163, city: geraldton
# Processing Record number 164, city: brae
# Processing Record number 165, city: ouadda
# Processing Record number 166, city: lerwick
# Processing Record number 167, city: nemuro
# City not found. Skipping...
# Processing Record number 169, city: san quintin
# Processing Record number 170, city: vostok
# Processing Record number 171, city: ponta do sol
# Processing Record number 172, city: thompson
# Processing Record number 173, city: prainha
# Processing Record number 174, city: sar-e pul
# Processing Record number 175, city: yarmouth
# Processing Record number 176, city: kuala terengganu
# City not found. Skipping...
# Processing Record number 178, city: iskateley
# Processing Record number 179, city: coahuayana
# Processing Record number 180, city: khatanga
# City not found. Skipping...
# Processing Record number 182, city: georgetown
# Processing Record number 183, city: alta floresta
# Processing Record number 184, city: conakry
# Processing Record number 185, city: kupang
# City not found. Skipping...
# Processing Record number 187, city: xuanhua
# Processing Record number 188, city: panama city
# Processing Record number 189, city: phitsanulok
# Processing Record number 190, city: hithadhoo
# Processing Record number 191, city: voh
# Processing Record number 192, city: iskenderun
# Processing Record number 193, city: sao paulo de olivenca
# Processing Record number 194, city: mount isa
# Processing Record number 195, city: dikson
# Processing Record number 196, city: katobu
# Processing Record number 197, city: paujiles
# Processing Record number 198, city: yumen
# Processing Record number 199, city: catuday
# Processing Record number 200, city: huarmey
# Processing Record number 201, city: kodiak
# Processing Record number 202, city: pascagoula
# Processing Record number 203, city: iqaluit
# Processing Record number 204, city: parkes
# Processing Record number 205, city: jiazi
# Processing Record number 206, city: lebu
# Processing Record number 207, city: tabou
# Processing Record number 208, city: san jeronimo
# City not found. Skipping...
# Processing Record number 210, city: richards bay
# Processing Record number 211, city: voloshka
# City not found. Skipping...
# Processing Record number 213, city: kaduqli
# Processing Record number 214, city: hasaki
# Processing Record number 215, city: souillac
# Processing Record number 216, city: swan hill
# Processing Record number 217, city: faanui
# Processing Record number 218, city: saraland
# Processing Record number 219, city: lermontovka
# Processing Record number 220, city: tasiilaq
# Processing Record number 221, city: yeppoon
# Processing Record number 222, city: cidreira
# Processing Record number 223, city: esperance
# City not found. Skipping...
# Processing Record number 225, city: sur
# Processing Record number 226, city: bonthe
# Processing Record number 227, city: akureyri
# Processing Record number 228, city: los llanos de aridane
# Processing Record number 229, city: langham
# Processing Record number 230, city: muyezerskiy
# Processing Record number 231, city: saint-georges
# Processing Record number 232, city: ambanja
# Processing Record number 233, city: mahon
# Processing Record number 234, city: lehigh acres
# Processing Record number 235, city: dwarka
# Processing Record number 236, city: tessalit
# Processing Record number 237, city: zhangye
# Processing Record number 238, city: east london
# Processing Record number 239, city: republic
# Processing Record number 240, city: nuuk
# Processing Record number 241, city: gelibolu
# City not found. Skipping...
# Processing Record number 243, city: delbruck
# Processing Record number 244, city: faya
# Processing Record number 245, city: saint-joseph
# Processing Record number 246, city: mersing
# Processing Record number 247, city: carnarvon
# Processing Record number 248, city: bamenda
# Processing Record number 249, city: lasa
# City not found. Skipping...
# Processing Record number 251, city: beringovskiy
# Processing Record number 252, city: oksfjord
# Processing Record number 253, city: barre
# Processing Record number 254, city: pacific grove
# Processing Record number 255, city: katsuura
# Processing Record number 256, city: khambhaliya
# Processing Record number 257, city: surab
# Processing Record number 258, city: balkhash
# Processing Record number 259, city: umea
# Processing Record number 260, city: wajima
# Processing Record number 261, city: touros
# Processing Record number 262, city: cap malheureux
# Processing Record number 263, city: xinzhi
# Processing Record number 264, city: khilok
# Processing Record number 265, city: cape girardeau
# Processing Record number 266, city: lagoa
# Processing Record number 267, city: anadyr
# Processing Record number 268, city: westport
# Processing Record number 269, city: namibe
# Processing Record number 270, city: teya
# Processing Record number 271, city: taksimo
# Processing Record number 272, city: hofn
# Processing Record number 273, city: fukue
# Processing Record number 274, city: along
# City not found. Skipping...
# Processing Record number 276, city: norman wells
# Processing Record number 277, city: cruzeiro do sul
# Processing Record number 278, city: diffa
# Processing Record number 279, city: ostrovnoy
# Processing Record number 280, city: cherskiy
# Processing Record number 281, city: nhulunbuy
# Processing Record number 282, city: avarua
# Processing Record number 283, city: san cristobal
# Processing Record number 284, city: labuhan
# City not found. Skipping...
# Processing Record number 286, city: les cayes
# Processing Record number 287, city: luziania
# Processing Record number 288, city: neryungri
# Processing Record number 289, city: nantucket
# Processing Record number 290, city: la palma
# Processing Record number 291, city: kodinsk
# Processing Record number 292, city: tautira
# Processing Record number 293, city: riyadh
# Processing Record number 294, city: galesong
# Processing Record number 295, city: smithers
# Processing Record number 296, city: cheremushskiy
# Processing Record number 297, city: eydhafushi
# Processing Record number 298, city: zeya
# Processing Record number 299, city: rocha
# Processing Record number 300, city: sabang
# Processing Record number 301, city: kungurtug
# Processing Record number 302, city: atambua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record number 305, city: xuddur
# Processing Record number 306, city: tual
# Processing Record number 307, city: praia da vitoria
# Processing Record number 308, city: vila
# Processing Record number 309, city: sao filipe
# Processing Record number 310, city: petropavlovsk-kamchatskiy
# Processing Record number 311, city: porto novo
# Processing Record number 312, city: karlshamn
# Processing Record number 313, city: upernavik
# Processing Record number 314, city: oromocto
# Processing Record number 315, city: wageningen
# Processing Record number 316, city: lillooet
# Processing Record number 317, city: kharovsk
# City not found. Skipping...
# Processing Record number 319, city: bilma
# Processing Record number 320, city: ahuimanu
# Processing Record number 321, city: aklavik
# Processing Record number 322, city: tromso
# Processing Record number 323, city: makakilo city
# Processing Record number 324, city: nedumangad
# Processing Record number 325, city: tomakomai
# Processing Record number 326, city: honningsvag
# City not found. Skipping...
# Processing Record number 328, city: beyneu
# Processing Record number 329, city: andros town
# Processing Record number 330, city: general pico
# City not found. Skipping...
# Processing Record number 332, city: sainte-maxime
# Processing Record number 333, city: sao felix do xingu
# City not found. Skipping...
# Processing Record number 335, city: vilhena
# Processing Record number 336, city: red bluff
# Processing Record number 337, city: ilulissat
# Processing Record number 338, city: granadilla de abona
# City not found. Skipping...
# Processing Record number 340, city: port lincoln
# Processing Record number 341, city: port hardy
# Processing Record number 342, city: bandarbeyla
# Processing Record number 343, city: saldanha
# Processing Record number 344, city: beberibe
# Processing Record number 345, city: maniitsoq
# City not found. Skipping...
# City not found. Skipping...
# Processing Record number 348, city: barahona
# City not found. Skipping...
# Processing Record number 350, city: evensk
# Processing Record number 351, city: bonavista
# Processing Record number 352, city: srednekolymsk
# Processing Record number 353, city: saint george
# City not found. Skipping...
# Processing Record number 355, city: poso
# Processing Record number 356, city: kahului
# Processing Record number 357, city: merke
# Processing Record number 358, city: tarakan
# Processing Record number 359, city: panuco
# Processing Record number 360, city: ulaanbaatar
# Processing Record number 361, city: chapais
# Processing Record number 362, city: mirpur sakro
# Processing Record number 363, city: imbituba
# Processing Record number 364, city: hami
# Processing Record number 365, city: portland
# Processing Record number 366, city: madras
# Processing Record number 367, city: vao
# Processing Record number 368, city: clyde river
# Processing Record number 369, city: kosh-agach
# Processing Record number 370, city: ismailia
# Processing Record number 371, city: san ramon
# Processing Record number 372, city: muriti
# Processing Record number 373, city: kenora
# Processing Record number 374, city: denizli
# Processing Record number 375, city: mahajanga
# Processing Record number 376, city: coihaique
# Processing Record number 377, city: general roca
# Processing Record number 378, city: veraval
# Processing Record number 379, city: shache
# City not found. Skipping...
# Processing Record number 381, city: jalu
# Processing Record number 382, city: christchurch
# Processing Record number 383, city: thomasville
# Processing Record number 384, city: sorland
# Processing Record number 385, city: nioro
# Processing Record number 386, city: mama
# Processing Record number 387, city: marsaxlokk
# Processing Record number 388, city: wilmington
# Processing Record number 389, city: ilo
# Processing Record number 390, city: havre-saint-pierre
# Processing Record number 391, city: moranbah
# Processing Record number 392, city: aimores
# Processing Record number 393, city: poum
# Processing Record number 394, city: nishihara
# Processing Record number 395, city: ashland
# Processing Record number 396, city: ketchikan
# Processing Record number 397, city: kaduy
# Processing Record number 398, city: hauterive
# Processing Record number 399, city: lorengau
# Processing Record number 400, city: vila franca do campo
# Processing Record number 401, city: plastun
# Processing Record number 402, city: kavali
# Processing Record number 403, city: muli
# Processing Record number 404, city: laguna
# Processing Record number 405, city: caravelas
# Processing Record number 406, city: khandyga
# Processing Record number 407, city: abu samrah
# Processing Record number 408, city: otkaznoye
# Processing Record number 409, city: morococha
# Processing Record number 410, city: segou
# Processing Record number 411, city: luderitz
# Processing Record number 412, city: paita
# City not found. Skipping...
# Processing Record number 414, city: harper
# Processing Record number 415, city: moree
# Processing Record number 416, city: payson
# Processing Record number 417, city: sivas
# Processing Record number 418, city: big rapids
# Processing Record number 419, city: sistranda
# Processing Record number 420, city: basco
# Processing Record number 421, city: nyurba
# Processing Record number 422, city: madiun
# City not found. Skipping...
# Processing Record number 424, city: muros
# Processing Record number 425, city: baculin
# Processing Record number 426, city: xai-xai
# Processing Record number 427, city: palmer
# City not found. Skipping...
# City not found. Skipping...
# Processing Record number 430, city: kavieng
# City not found. Skipping...
# Processing Record number 432, city: palma gil
# Processing Record number 433, city: half moon bay
# Processing Record number 434, city: ahipara
# Processing Record number 435, city: kiyasovo
# Processing Record number 436, city: miles city
# Processing Record number 437, city: anzio
# Processing Record number 438, city: muana
# Processing Record number 439, city: chapada dos guimaraes
# Processing Record number 440, city: jinchang
# Processing Record number 441, city: atar
# Processing Record number 442, city: dauphin
# Processing Record number 443, city: bhigvan
# Processing Record number 444, city: mayo
# City not found. Skipping...
# Processing Record number 446, city: tezu
# Processing Record number 447, city: magadan
# Processing Record number 448, city: katherine
# Processing Record number 449, city: mountain home
# Processing Record number 450, city: sisimiut
# Processing Record number 451, city: progreso
# Processing Record number 452, city: mareeba
# Processing Record number 453, city: mezen
# City not found. Skipping...
# Processing Record number 455, city: hobbs
# City not found. Skipping...
# Processing Record number 457, city: karratha
# Processing Record number 458, city: sumy
# Processing Record number 459, city: yenagoa
# Processing Record number 460, city: ballina
# Processing Record number 461, city: coos bay
# Processing Record number 462, city: fort nelson
# City not found. Skipping...
# Processing Record number 464, city: komsomolskiy
# Processing Record number 465, city: san policarpo
# Processing Record number 466, city: sultanpur
# Processing Record number 467, city: doha
# City not found. Skipping...
# Processing Record number 469, city: longyearbyen
# City not found. Skipping...
# Processing Record number 471, city: zhanaozen
# Processing Record number 472, city: dali
# Processing Record number 473, city: padang
# Processing Record number 474, city: grootfontein
# Processing Record number 475, city: korem
# Processing Record number 476, city: sao goncalo do amarante
# Processing Record number 477, city: torbay
# City not found. Skipping...
# Processing Record number 479, city: flinders
# Processing Record number 480, city: fort-shevchenko
# City not found. Skipping...
# Processing Record number 482, city: mackay
# Processing Record number 483, city: kovdor
# Processing Record number 484, city: kibala
# Processing Record number 485, city: salinopolis
# Processing Record number 486, city: fairlie
# Processing Record number 487, city: coffs harbour
# Processing Record number 488, city: puerto leguizamo
# Processing Record number 489, city: camargo
# Processing Record number 490, city: muriwai beach
# Processing Record number 491, city: busdi
# Processing Record number 492, city: tagusao
# Processing Record number 493, city: kamaishi
# Processing Record number 494, city: huilong
# Processing Record number 495, city: necochea
# Processing Record number 496, city: nueve de julio
# Processing Record number 497, city: schneeberg
# Processing Record number 498, city: pevek
# Processing Record number 499, city: paamiut
# Processing Record number 500, city: nome
# Processing Record number 501, city: port blair
# Processing Record number 502, city: buin
# Processing Record number 503, city: eregli
# Processing Record number 504, city: olden
# Processing Record number 505, city: butajira
# Processing Record number 506, city: minas
# Processing Record number 507, city: koutsouras
# Processing Record number 508, city: orbetello
# Processing Record number 509, city: ajdabiya
# Processing Record number 510, city: maldonado
# Processing Record number 511, city: codrington
# Processing Record number 512, city: koygorodok
# Processing Record number 513, city: goderich
# Processing Record number 514, city: honiara
# Processing Record number 515, city: quelimane
# Processing Record number 516, city: ploemeur
# Processing Record number 517, city: lethem
# Processing Record number 518, city: rio gallegos
# Processing Record number 519, city: santa maria
# Processing Record number 520, city: angoche
# Processing Record number 521, city: virginia beach
# Processing Record number 522, city: olonets
# Processing Record number 523, city: san vicente
# Processing Record number 524, city: constantine
# Processing Record number 525, city: kutum
# Processing Record number 526, city: saint pete beach
# Processing Record number 527, city: davidson
# Processing Record number 528, city: pitimbu
# Processing Record number 529, city: fort saint james
# Processing Record number 530, city: madang
# Processing Record number 531, city: saint-pierre
# Processing Record number 532, city: lokosovo
# Processing Record number 533, city: goulburn
# Processing Record number 534, city: straumen
# City not found. Skipping...
# Processing Record number 536, city: marawi
# Processing Record number 537, city: ravar
# Processing Record number 538, city: quatre cocos
# Processing Record number 539, city: salinas
# Processing Record number 540, city: itacoatiara
# Processing Record number 541, city: marrakesh
# Processing Record number 542, city: talcahuano
# Processing Record number 543, city: perth
# Processing Record number 544, city: hayrabolu
# Processing Record number 545, city: piro
# Processing Record number 546, city: nanakuli
# Processing Record number 547, city: kulhudhuffushi
# Processing Record number 548, city: gat
# Processing Record number 549, city: den helder
# Processing Record number 550, city: shatrovo
# Processing Record number 551, city: belaya gora
# Processing Record number 552, city: beisfjord
# Processing Record number 553, city: santa luzia
# Processing Record number 554, city: yulara
# Processing Record number 555, city: zaraza
# Processing Record number 556, city: broken hill
# Processing Record number 557, city: kavaratti
# Processing Record number 558, city: vanavara
# City not found. Skipping...
# Processing Record number 560, city: margate
# Processing Record number 561, city: wanning
# Processing Record number 562, city: luganville
# Processing Record number 563, city: atraulia
# City not found. Skipping...
# Processing Record number 565, city: santa isabel do rio negro
# Processing Record number 566, city: ridgecrest
# Processing Record number 567, city: inverness
# Processing Record number 568, city: barbacoas
# Processing Record number 569, city: mahibadhoo
# City not found. Skipping...
# Processing Record number 571, city: poykovskiy
# Processing Record number 572, city: mazagao
# Processing Record number 573, city: edd
# Processing Record number 574, city: kasongo-lunda
# Processing Record number 575, city: ust-barguzin
# Processing Record number 576, city: springbok
# Processing Record number 577, city: loandjili
# Processing Record number 578, city: macae
# Processing Record number 579, city: hirara
# Processing Record number 580, city: buraydah
# Processing Record number 581, city: el tigre
# Processing Record number 582, city: aromashevo
# Processing Record number 583, city: la ronge
# Processing Record number 584, city: san pedro
# Processing Record number 585, city: nicolae balcescu
# Processing Record number 586, city: rawson
# Processing Record number 587, city: fengrun
# Processing Record number 588, city: were ilu
# Processing Record number 589, city: lardos
# City not found. Skipping...
# Processing Record number 591, city: pisco
# Processing Record number 592, city: aldan
# Processing Record number 593, city: pundaguitan
# Processing Record number 594, city: amazar
# Processing Record number 595, city: inirida
# Processing Record number 596, city: montrose
# Processing Record number 597, city: dunda
# Processing Record number 598, city: najran
# Processing Record number 599, city: yar-sale
# City not found. Skipping...
# Processing Record number 601, city: hanstholm
# Processing Record number 602, city: dicabisagan
# Processing Record number 603, city: dakar
# City not found. Skipping...
# Processing Record number 605, city: la rioja
# Processing Record number 606, city: nicoya
# Processing Record number 607, city: nanortalik

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Conver raw data to DataFrame
city_data_df = pd.DataFrame(city_data_list, columns=data.keys())
city_data_df.count()
# Out:
# City          542
# Country       542
# Cloudiness    542
# Date          542
# Humidity      542
# Latitude      542
# Longitude     542
# Max Temp      542
# Wind Speed    542
# dtype: int64

# %%
# Export the city data into a.csv.
city_data_df.to_csv(output_data_file, index=False)

# Display a preview of the DataFrame
city_data_df.head()
# Out:
#         City Country  Cloudiness        Date  Humidity  Latitude  Longitude  \
# 0  Mahebourg      MU          20  1571864103        88    -20.41      57.70
# 1    Iturama      BR          97  1571864397        55    -19.73     -50.20
# 2      Kapaa      US          20  1571863815        69     22.08    -159.32
# 3   Hermanus      ZA         100  1571864397        81    -34.42      19.24
# 4   Plouzane      FR          90  1571864398        93     48.38      -4.62
#
#    Max Temp  Wind Speed
# 0     73.00        5.82
# 1     81.90        8.41
# 2     82.40        8.05
# 3     57.99        3.00
# 4     55.40        2.24

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for Latitude vs Temperature.
plt.scatter(city_data_df['Latitude'], city_data_df['Max Temp'], c='cyan',
            marker='o', edgecolors='dimgray')

# Incorporate the other graph properties
plt.ylim(-5, 105)
plt.title('City Latitude vs. Max Temperature (10/23/2019)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.grid(True)

# Save the figure as .png.
plt.savefig('C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/Images/Latitude-MaxTemp.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for Latitude vs Humidity.
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'], c='purple',
            marker='o', edgecolors='dimgray')

# Incorporate the other graph properties
plt.ylim(-5, 105)
plt.title('City Latitude vs. Humidity (10/23/2019)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure as .png.
plt.savefig('C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/Images/Latitude-Humidity.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for Latitude vs Cloudiness.
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'], c='silver',
            marker='o', edgecolors='maroon')

# Incorporate the other graph properties
plt.ylim(-5, 105)
plt.title('City Latitude vs. Cloudiness (10/23/2019)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure as .png.
plt.savefig('C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/Images/Latitude-Cloudiness.png')

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for Latitude vs Wind Speed.
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'], c='maroon',
            marker='o', edgecolors='dimgray')

# Incorporate the other graph properties
plt.ylim(-5, max(city_data_df['Wind Speed'])+5)
plt.title('City Latitude vs. Wind Speed (10/23/2019)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

# Save the figure as .png.
plt.savefig('C:/Users/Jenni/UNCCDABC/Homeworks/python-api-challenge/WeatherPy/Images/Latitude-Wind Speed.png')

# Show plot
plt.show()
